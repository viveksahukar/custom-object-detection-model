# %%
import os
import torch
import torchvision
import xml.etree.ElementTree as ET
from PIL import Image
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision import transforms
from torchvision.models.detection import FasterRCNN, fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.transforms import functional as F
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Set random seed for reproducibility
random_seed = 42
torch.manual_seed(random_seed)

# %%
# Paths
train_val_path = "train"
test_path = "valid"

# List all images and annotations for training/validation set
images = [os.path.join(train_val_path, f) for f in os.listdir(train_val_path) if f.endswith('.jpg')]
annotations = [os.path.join(train_val_path, f) for f in os.listdir(train_val_path) if f.endswith('.xml')]

# List all images and annotations for test set
test_images = [os.path.join(test_path, f) for f in os.listdir(test_path) if f.endswith('.jpg')]
test_annotations = [os.path.join(test_path, f) for f in os.listdir(test_path) if f.endswith('.xml')]

# Ensure images and annotations are aligned
images.sort()
annotations.sort()
test_images.sort()
test_annotations.sort()

# %%
# Mapping Pascal VOC classes to numerical labels
VOC_CLASSES = {
    "aeroplane": 1, "bicycle": 2, "bird": 3, "boat": 4, "bottle": 5,
    "bus": 6, "car": 7, "cat": 8, "chair": 9, "cow": 10,
    "diningtable": 11, "dog": 12, "horse": 13, "motorbike": 14, "person": 15,
    "pottedplant": 16, "sheep": 17, "sofa": 18, "train": 19, "tvmonitor": 20
}

class PascalVOCDataset(Dataset):
    def __init__(self, image_paths, annotation_paths, transform=None):
        self.image_paths = image_paths
        self.annotation_paths = annotation_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        annotation_path = self.annotation_paths[idx]
        image = Image.open(img_path).convert("RGB")
        
        # Load annotations (bounding boxes and labels)
        boxes, labels = self.load_annotations(annotation_path)

        # Debug: print annotations for verification
        # print(f"Image {img_path}, boxes: {boxes}, labels: {labels}")
        
        if self.transform:
            image = self.transform(image)
        
        target = {
            "boxes": boxes,
            "labels": labels
        }
        
        return image, target

    def load_annotations(self, annotation_path):
        # Parse the XML annotation file and extract bounding boxes and labels
        boxes = []
        labels = []
        tree = ET.parse(annotation_path)
        root = tree.getroot()
        
        for obj in root.findall("object"):
            label = obj.find("name").text
            bbox = obj.find("bndbox")
            xmin = int(bbox.find("xmin").text)
            ymin = int(bbox.find("ymin").text)
            xmax = int(bbox.find("xmax").text)
            ymax = int(bbox.find("ymax").text)
            boxes.append([xmin, ymin, xmax, ymax])
            # Assign the correct label based on the object name
            labels.append(VOC_CLASSES[label])
        
        return torch.tensor(boxes, dtype=torch.float32), torch.tensor(labels, dtype=torch.int64)

# This handles multi-class detection and retrieves annotations for all classes.

# %%
# Define the transformation pipeline (resizing and normalization)
def transform(image):
    return transforms.Compose([
        transforms.Resize((224, 224)),  # Resize image to 224x224
        transforms.ToTensor(),  # Convert image to tensor
        transforms.Normalize(mean=[0.485, 0.456, 0.406],  # Normalize using ImageNet stats
                             std=[0.229, 0.224, 0.225])
    ])(image)


# Initialize datasets
full_dataset = PascalVOCDataset(images, annotations, transform=transform)
test_dataset = PascalVOCDataset(test_images, test_annotations, transform=transform)

# Create data loaders
def collate_fn(batch):
    return tuple(zip(*batch))

# Define the IoU calculation function
def calculate_iou(outputs, targets, threshold=0.5):
    ious = []
    for i in range(len(outputs)):
        pred_boxes = outputs[i]['boxes'].cpu().numpy()
        true_boxes = targets[i]['boxes'].cpu().numpy()
        pred_labels = outputs[i]['labels'].cpu().numpy()
        true_labels = targets[i]['labels'].cpu().numpy()

        for j, pred_box in enumerate(pred_boxes):
            pred_label = pred_labels[j]
            for k, true_box in enumerate(true_boxes):
                true_label = true_labels[k]
                
                # Only compute IoU if the predicted and true labels are the same
                if pred_label == true_label:
                    iou = compute_iou(pred_box, true_box)
                    if iou >= threshold:
                        ious.append(iou)
    return sum(ious) / len(ious) if ious else 0

# Compute the IoU of two bounding boxes (no change needed here)
def compute_iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1g, y1g, x2g, y2g = box2

    xi1 = max(x1, x1g)
    yi1 = max(y1, y1g)
    xi2 = min(x2, x2g)
    yi2 = min(y2, y2g)
    inter_area = max(0, xi2 - xi1 + 1) * max(0, yi2 - yi1 + 1)

    box1_area = (x2 - x1 + 1) * (y2 - y1 + 1)
    box2_area = (x2g - x1g + 1) * (y2g - y1g + 1)

    union_area = box1_area + box2_area - inter_area

    return inter_area / union_area

# %%
# Generate and evaluate different train/valid splits
results = {}
test_results = {}

n_samples = len(images)
print(f"Total number of samples: {n_samples}")

for i in range(1, 10):
    train_size = i * 0.1
    print(f"\nIteration {i}, train_size: {train_size:.1f}")

    # Ensure the training set has at least one sample
    adjusted_train_size = max(int(n_samples * train_size), 1)
    adjusted_valid_size = n_samples - adjusted_train_size

    if adjusted_valid_size == 0:
        print(f"Skipping iteration {i} as there are no validation samples.")
        continue

    print(f"Adjusted train size: {adjusted_train_size}, validation size: {adjusted_valid_size}")

    # Split the dataset
    train_indices, valid_indices = train_test_split(range(n_samples), train_size=adjusted_train_size, random_state=random_seed)
    print(f"Number of training samples: {len(train_indices)}")
    print(f"Number of validation samples: {len(valid_indices)}")

    # Check for empty training set
    if len(train_indices) == 0:
        print("Error: Train set is empty!")
        continue

    train_loader = DataLoader(Subset(full_dataset, train_indices), batch_size=4, shuffle=True, collate_fn=collate_fn)
    valid_loader = DataLoader(Subset(full_dataset, valid_indices), batch_size=4, shuffle=False, collate_fn=collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, collate_fn=collate_fn)

    # Load the pre-trained Faster R-CNN model
    model = fasterrcnn_resnet50_fpn(pretrained=True)

    # Replace the box predictor with a new one for Pascal VOC's 20 classes + background
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    num_classes = 21  # 20 object classes + background
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # Move model to GPU if available
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
    model.to(device)

    # Fine-tune the model
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    num_epochs = 10

    # model training
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for images, targets in train_loader:
            # Only continue if the batch contains valid bounding boxes
            if any(len(t['boxes']) == 0 for t in targets):
                print(f"Skipping batch with empty targets: {[len(t['boxes']) for t in targets]}")
                continue
            
            images = list(image.to(device) for image in images)
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            optimizer.zero_grad()
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
            losses.backward()
            optimizer.step()
            running_loss += losses.item()

        print(f"Epoch {epoch+1}, Loss: {running_loss/len(train_loader)}")


    # Evaluate the model on the validation set
    model.eval()
    val_mean_iou = 0.0
    with torch.no_grad():
        for images, targets in valid_loader:
            images = list(image.to(device) for image in images)
            
            # During evaluation, just pass the images (no targets)
            outputs = model(images)
            
            # Calculate IoU for validation set (uses multi-class IoU function)
            batch_iou = calculate_iou(outputs, targets)
            val_mean_iou += batch_iou

    val_mean_iou /= len(valid_loader)
    print(f"Validation Mean IoU: {val_mean_iou}")
    results[f"split_{i}"] = val_mean_iou

    # Evaluate the model on the test set
    test_mean_iou = 0.0
    with torch.no_grad():
        for images, targets in test_loader:
            images = list(image.to(device) for image in images)
            
            # During evaluation, just pass the images (no targets)
            outputs = model(images)
            
            # Calculate IoU for test set (uses multi-class IoU function)
            batch_iou = calculate_iou(outputs, targets)
            test_mean_iou += batch_iou

    test_mean_iou /= len(test_loader)
    print(f"Test Mean IoU: {test_mean_iou}")
    test_results[f"split_{i}"] = test_mean_iou
# Out:
# Total number of samples: 13690
#
# Iteration 1, train_size: 0.1
# Adjusted train size: 1369, validation size: 12321
# Number of training samples: 1369
# Number of validation samples: 12321
# /home/vs/miniconda3/envs/objdet/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/vs/miniconda3/envs/objdet/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Image train/2011_001592_jpg.rf.0c269fc0752f4137d8fc3f3bb06aea22.jpg, boxes: tensor([[  1.,   2., 434., 319.]]), labels: tensor([4])
# Image train/2008_003466_jpg.rf.6a4560016bfc94ba8e48b098b0636fc3.jpg, boxes: tensor([[128.,  73., 357., 287.],
#         [448.,   1., 500., 262.]]), labels: tensor([20, 16])
# Image train/2008_003252_jpg.rf.baaf66bd733eacccc78dc04ab366f75f.jpg, boxes: tensor([[136.,  77., 436., 373.]]), labels: tensor([9])
# Image train/2012_003662_jpg.rf.d37319455f377f77d3c518649920e641.jpg, boxes: tensor([[250., 101., 296., 175.]]), labels: tensor([15])
# Image train/2012_003987_jpg.rf.6084911012ad2a1e071986e42f764a9a.jpg, boxes: tensor([[235.,  97., 415., 369.],
#         [140., 173., 257., 365.],
#         [ 58., 161., 139., 410.]]), labels: tensor([15, 15, 15])
# Image train/2008_002697_jpg.rf.3c748708cd5deaa2f18398958ff66124.jpg, boxes: tensor([[ 69., 116., 333., 347.]]), labels: tensor([13])
# Image train/2009_001075_jpg.rf.f35cdcc711c713a7ec45e647d9a4d788.jpg, boxes: tensor([[177.,  58., 500., 251.],
#         [ 57.,  88., 500., 375.]]), labels: tensor([12, 12])
# Image train/2009_000340_jpg.rf.33c884fa04e808d54227363a74a07f3a.jpg, boxes: tensor([[ 16., 356.,  71., 500.],
#         [260., 332., 375., 500.],
#         [ 43., 250., 101., 395.],
#         [147.,  63., 185., 165.],
#         [ 35., 157., 326., 500.]]), labels: tensor([15, 15,  5,  5, 15])
# Image train/2010_003086_jpg.rf.e8ee0cdc92d4a14bfa5d9817de5d9d09.jpg, boxes: tensor([[  1.,   1., 500., 375.]]), labels: tensor([12])
# Image train/2008_003825_jpg.rf.1ef08fb610b221dbeda148b1fe7b25d8.jpg, boxes: tensor([[  1., 345., 269., 417.],
#         [ 23.,  60., 184., 314.],
#         [172., 297., 241., 351.],
#         [272.,  12., 404., 416.],
#         [350.,  24., 422., 414.],
#         [371.,   1., 500., 416.],
#         [ 81., 360., 148., 417.]]), labels: tensor([20, 15, 15, 15, 15, 15, 15])
# Image train/2010_000749_jpg.rf.3862705343e46d61271d4655452f08a6.jpg, boxes: tensor([[ 63., 135., 307., 307.]]), labels: tensor([13])
# Image train/2011_004037_jpg.rf.f62697b3aae8ea69f12bfea575322e7b.jpg, boxes: tensor([[101.,  17., 398., 333.]]), labels: tensor([15])
# Image train/2011_005938_jpg.rf.27a122f58220826f30f85ec6e54123e6.jpg, boxes: tensor([[235., 137., 280., 218.]]), labels: tensor([15])
# Image train/2011_003602_jpg.rf.ed2ff7fef69aff8e6e4c3c735fa1a8cc.jpg, boxes: tensor([[ 73.,  22., 482., 375.]]), labels: tensor([15])
# Image train/2010_002215_jpg.rf.a2802aacefb7c7bfc51669a4b9fc079e.jpg, boxes: tensor([[  1.,   2.,  36.,  68.],
#         [ 16.,  68., 157., 219.],
#         [174.,  88., 326., 294.]]), labels: tensor([17, 17, 17])
# Image train/2011_001064_jpg.rf.015351dfeccb5d4671f846d2c10ec8ba.jpg, boxes: tensor([[ 61., 130., 470., 291.],
#         [470., 164., 500., 245.]]), labels: tensor([6, 6])
# Image train/2012_004158_jpg.rf.84d160dda546c294d7b5b6b3f7a5dd1e.jpg, boxes: tensor([[206., 112., 295., 375.]]), labels: tensor([15])
# Image train/2007_001175_jpg.rf.7a40cbd049aa8e953312042acbee8de2.jpg, boxes: tensor([[119., 153., 367., 329.],
#         [157., 169., 256., 230.],
#         [360., 114., 449., 187.]]), labels: tensor([15, 15, 20])
# Image train/2009_003365_jpg.rf.fbd1820f6cef47935a3bbd4e6dbad8d8.jpg, boxes: tensor([[  1.,  22., 130., 371.],
#         [111., 195., 333., 500.]]), labels: tensor([15, 13])
# Image train/2009_003581_jpg.rf.34cc6d7e1b19508ae80eda888f1e69bf.jpg, boxes: tensor([[  1., 237., 311., 472.],
#         [ 65., 138., 280., 500.]]), labels: tensor([18, 15])
# Image train/2008_006463_jpg.rf.0f6eb3e4b26028b49973db066cea169b.jpg, boxes: tensor([[  1.,  82., 494., 281.]]), labels: tensor([1])
# Image train/2008_007486_jpg.rf.c89c3f2c41873e8b47665add5057a89f.jpg, boxes: tensor([[199.,  94., 500., 375.],
#         [  1., 177., 200., 338.]]), labels: tensor([12,  3])
# Image train/2011_002853_jpg.rf.e1adc0f08261ff95c62f248346a0ce6c.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2012_002725_jpg.rf.a406e4f2ab37a29c5845b5c823b5c30b.jpg, boxes: tensor([[150.,  53., 308., 304.]]), labels: tensor([15])
# Skipping batch with empty targets: [1, 2, 0, 1]
# Image train/2009_005000_jpg.rf.1a162a5cc21d20474c2a4a7b4f0c916c.jpg, boxes: tensor([[ 37.,  48., 275., 500.]]), labels: tensor([13])
# Image train/2011_002885_jpg.rf.615bfe1e5eab93283c48befbc3fd90bb.jpg, boxes: tensor([[109., 101., 397., 276.],
#         [463., 156., 500., 236.],
#         [  1., 109., 111., 269.]]), labels: tensor([10, 10, 10])
# Image train/2008_005369_jpg.rf.8c7c0ab8ecd0d89e1039fbc69bf2b78a.jpg, boxes: tensor([[243., 196., 421., 375.],
#         [  1.,   1., 294., 375.]]), labels: tensor([13, 13])
# Image train/2010_006067_jpg.rf.5667573f4c2e654e1728774175d48846.jpg, boxes: tensor([[161., 110., 336., 159.]]), labels: tensor([1])
# Image train/2010_001087_jpg.rf.27e69882f56812a8d1854fd2fc6404e5.jpg, boxes: tensor([[ 36.,  13., 404., 316.],
#         [339.,  82., 500., 253.]]), labels: tensor([6, 6])
# Image train/2009_000600_jpg.rf.58ad0fbe23a7cff51f1879fb730d583d.jpg, boxes: tensor([[179.,  37., 472., 333.],
#         [ 40.,   1., 309., 166.]]), labels: tensor([12, 12])
# Image train/2010_001412_jpg.rf.8008121031dbd273ad23ca0284da5d06.jpg, boxes: tensor([[232.,   1., 486., 222.],
#         [165.,  90., 278., 270.],
#         [173.,  46., 221., 103.]]), labels: tensor([13, 15, 15])
# Image train/2008_005603_jpg.rf.b165f31e7b4fb127407e93df5a49273d.jpg, boxes: tensor([[ 10.,  34., 451., 241.]]), labels: tensor([14])
# Image train/2012_003955_jpg.rf.513ddf2851cf6bcc2ced2a08b065fc93.jpg, boxes: tensor([[255.,  38., 376., 445.],
#         [151.,  35., 290., 448.]]), labels: tensor([15, 15])
# Image train/2008_008423_jpg.rf.ed0c7fddec0bef80544f5256c96e5657.jpg, boxes: tensor([[244., 224., 279., 263.]]), labels: tensor([3])
# Image train/2008_005316_jpg.rf.569285e11286a0d2d7b4f0a7b2118b57.jpg, boxes: tensor([[314., 280., 359., 375.],
#         [203., 225., 229., 275.],
#         [244., 233., 312., 279.],
#         [ 54., 213., 191., 273.]]), labels: tensor([15, 15,  7,  7])
# Image train/2011_001896_jpg.rf.0c51c5973d762e126879f2f1f46a21b2.jpg, boxes: tensor([[232., 174., 388., 326.]]), labels: tensor([2])
# Image train/2011_000382_jpg.rf.70c08e7d09dc9a4e5ff2f69f682ff8ca.jpg, boxes: tensor([[ 13.,  55., 128., 184.],
#         [117.,  28., 280., 137.],
#         [455., 155., 475., 190.],
#         [211., 158., 500., 375.]]), labels: tensor([20, 20,  5,  9])
# Image train/2012_004104_jpg.rf.7ea2dd9e7d11a272d1938368f707a14e.jpg, boxes: tensor([[216.,  68., 318., 303.]]), labels: tensor([15])
# Image train/2010_003675_jpg.rf.5dc170bd1724f8fe81f5b29179f01df4.jpg, boxes: tensor([[  9.,  61., 500., 374.]]), labels: tensor([8])
# Image train/2010_006400_jpg.rf.ccc861ed13165ae807846b4e5bddd6c1.jpg, boxes: tensor([[137.,  67., 298., 375.]]), labels: tensor([15])
# Image train/2012_003107_jpg.rf.013eeb158b802472cb768059c2260356.jpg, boxes: tensor([[209.,  21., 418., 375.]]), labels: tensor([15])
# Image train/2009_003666_jpg.rf.5b4db3397bcf1e6a5554e85de0d4a07f.jpg, boxes: tensor([[408., 133., 500., 287.],
#         [237., 139., 326., 305.],
#         [ 83., 125., 227., 294.],
#         [  1., 101., 136., 243.],
#         [278., 114., 363., 189.]]), labels: tensor([17, 17, 17, 17, 17])
# Image train/2010_001649_jpg.rf.7e05a18e3aeee876043fcc5147616b94.jpg, boxes: tensor([[ 86.,   1., 500., 375.]]), labels: tensor([15])
# Image train/2009_002438_jpg.rf.c0b87c2870053a72656ea8353cb94551.jpg, boxes: tensor([[ 26.,  41., 480., 359.]]), labels: tensor([2])
# Image train/2011_003576_jpg.rf.0d1162db1f55c5518d2e085946a84bdd.jpg, boxes: tensor([[144.,  17., 362., 374.]]), labels: tensor([15])
# Image train/2010_005536_jpg.rf.1921eeb167d70549964c0cd60e72fb4a.jpg, boxes: tensor([[ 62., 256., 213., 375.],
#         [286.,  17., 380., 101.],
#         [216., 204., 349., 353.],
#         [300., 153., 437., 323.],
#         [353., 133., 478., 241.],
#         [331.,  57., 396., 125.],
#         [351.,  85., 439., 145.]]), labels: tensor([16, 16, 16, 16, 16, 16, 16])
# Image train/2008_001871_jpg.rf.66448bf92c7537ec45d5610726b12768.jpg, boxes: tensor([[ 59.,  62., 258., 400.]]), labels: tensor([12])
# Image train/2011_003028_jpg.rf.b39385c5090790c590e00f3846cc7f82.jpg, boxes: tensor([[ 76., 140., 384., 360.],
#         [330., 142., 500., 354.]]), labels: tensor([19, 19])
# Image train/2010_004730_jpg.rf.fe52ce39768814f91400cd125581285d.jpg, boxes: tensor([[ 60.,  44., 494., 354.]]), labels: tensor([12])
# Image train/2008_000858_jpg.rf.b7afa2f17cf9622b8e4f39e5736999c9.jpg, boxes: tensor([[ 12.,  51., 382., 328.],
#         [284.,  16., 453., 211.]]), labels: tensor([14, 14])
# Image train/2011_007071_jpg.rf.186947f4dde08c7597db90fad4c4d7c8.jpg, boxes: tensor([[139., 173., 212., 409.]]), labels: tensor([15])
# Image train/2009_000290_jpg.rf.7d7816997102a39211318f16691e1e54.jpg, boxes: tensor([[201., 161., 266., 201.],
#         [357., 174., 366., 199.],
#         [368., 171., 376., 197.],
#         [130., 181., 141., 190.]]), labels: tensor([ 6, 15, 15,  7])
# Image train/2008_000128_jpg.rf.6f430cfbb2b2331546fe526868792e3e.jpg, boxes: tensor([[ 11.,  29., 500., 375.],
#         [ 92., 173., 212., 357.]]), labels: tensor([18, 15])
# Image train/2009_002221_jpg.rf.6be764335c8469e2b6519c3158417038.jpg, boxes: tensor([[  1.,  61., 357., 375.],
#         [299.,  94., 500., 375.]]), labels: tensor([10, 10])
# Image train/2008_005978_jpg.rf.f5284bf3f87b17d9a2587ae80f56f61d.jpg, boxes: tensor([[ 47.,  53., 222., 475.],
#         [ 44., 248., 194., 500.]]), labels: tensor([15,  2])
# Image train/2012_002479_jpg.rf.487a108f8cd4587ffbeb6fd8ad04e1eb.jpg, boxes: tensor([[156.,  40., 350., 336.]]), labels: tensor([15])
# Image train/2012_002949_jpg.rf.b6bebab3da3dc675db2f67478f89fd1c.jpg, boxes: tensor([[356., 220., 424., 333.],
#         [214., 223., 290., 336.]]), labels: tensor([15, 15])
# Image train/2011_005341_jpg.rf.45a666e5c8421343a73522a2755351a5.jpg, boxes: tensor([[  1.,   1., 500., 375.]]), labels: tensor([15])
# Image train/2011_001327_jpg.rf.7b7c8a863b31bc5ed613fc8aa2d04c1f.jpg, boxes: tensor([[253., 197., 295., 309.],
#         [156., 128., 349., 375.],
#         [  1., 247.,  77., 375.]]), labels: tensor([ 5, 15, 15])
# Image train/2012_003101_jpg.rf.991c46b5c04e1e4a966c28452f0eecfd.jpg, boxes: tensor([[162.,  22., 352., 375.]]), labels: tensor([15])
# Image train/2010_006790_jpg.rf.d67a390056ea3886a20dbea89da593f1.jpg, boxes: tensor([[182.,  96., 342., 375.]]), labels: tensor([15])
# Image train/2011_007186_jpg.rf.9af959e8baf85cd3a458c775f9dc4125.jpg, boxes: tensor([[292., 151., 385., 303.]]), labels: tensor([15])
# Image train/2012_000880_jpg.rf.5a914511a06fb906ead6b724ff028a74.jpg, boxes: tensor([[302.,  91., 404., 375.],
#         [262., 121., 322., 328.],
#         [ 88., 128., 176., 284.]]), labels: tensor([15, 15, 15])
# Image train/2008_002601_jpg.rf.249b0d8d64fc4d8035ae22fdb4c1d600.jpg, boxes: tensor([[ 18.,  20., 372., 500.],
#         [251., 301., 383., 386.],
#         [232., 283., 295., 325.],
#         [  1.,  18., 401., 500.]]), labels: tensor([15, 15,  5,  9])
# Image train/2011_000086_jpg.rf.06637098c7600ae5f5e20c953ef01e60.jpg, boxes: tensor([[ 62., 124., 446., 293.],
#         [ 11.,  57., 146., 105.]]), labels: tensor([7, 4])
# Image train/2011_005724_jpg.rf.29bebadef9bd967489653fc3b63fca5a.jpg, boxes: tensor([[185., 151., 252., 350.],
#         [244., 176., 273., 269.],
#         [313., 143., 364., 326.]]), labels: tensor([15, 15, 15])
# Image train/2011_000286_jpg.rf.88072683a9aae8616533f20251dadea3.jpg, boxes: tensor([[128., 232., 230., 283.],
#         [  1., 252., 291., 375.],
#         [245., 254., 334., 298.],
#         [351., 228., 433., 294.],
#         [425., 230., 500., 296.],
#         [241., 205., 310., 259.],
#         [299., 220., 370., 268.]]), labels: tensor([4, 4, 4, 4, 4, 4, 4])
# Image train/2008_003330_jpg.rf.3d1f89d15a5ab5f84d3de55ca443f260.jpg, boxes: tensor([[  1.,  71., 270., 360.]]), labels: tensor([15])
# Image train/2010_001891_jpg.rf.a688cb1263466589e9dba758683028f8.jpg, boxes: tensor([[142., 139., 286., 371.],
#         [106.,   1., 295., 360.]]), labels: tensor([12, 15])
# Image train/2009_003810_jpg.rf.b4e6bc7a4df12494b3be9d16a678ddb2.jpg, boxes: tensor([[ 77.,  84., 488., 346.]]), labels: tensor([12])
# Image train/2007_004712_jpg.rf.fd03d656136c8018d18066486ed027cd.jpg, boxes: tensor([[101., 106., 380., 375.],
#         [  1., 169., 139., 375.],
#         [ 15., 156.,  43., 214.],
#         [  2., 146.,  32., 209.],
#         [ 47.,  48.,  73., 108.],
#         [335., 150., 370., 241.],
#         [344., 119., 380., 233.],
#         [205., 135., 262., 255.],
#         [164., 114., 229., 224.],
#         [406.,  62., 500., 269.]]), labels: tensor([15, 11,  5,  5,  5,  9,  9,  9,  9, 16])
# Image train/2011_004751_jpg.rf.3bbbbf1c2f73f39a4d5f9283c168b3ba.jpg, boxes: tensor([[105., 115., 185., 272.],
#         [308., 116., 372., 243.],
#         [167., 107., 249., 287.]]), labels: tensor([15, 15, 15])
# Image train/2009_004142_jpg.rf.ab11dad6855e304f15ed38caecb160f5.jpg, boxes: tensor([[ 43.,   1., 500., 281.],
#         [148.,  65., 236., 160.],
#         [  1.,  28., 116., 164.],
#         [  1., 108.,  69., 281.],
#         [205.,  76., 242., 174.]]), labels: tensor([15, 15, 15, 15, 15])
# Image train/2008_003135_jpg.rf.e7550d86c7f0709bb4c4c1ce4c89f312.jpg, boxes: tensor([[258., 324., 335., 460.],
#         [  1., 270.,  50., 443.]]), labels: tensor([16, 16])
# Image train/2009_002245_jpg.rf.22cc83674fe388c6b74c30be86189565.jpg, boxes: tensor([[142.,  65., 500., 333.]]), labels: tensor([17])
# Image train/2010_004459_jpg.rf.e635f0a99d1d7aff074cd3a9830aaf13.jpg, boxes: tensor([[ 14.,  88., 482., 338.]]), labels: tensor([7])
# Image train/2010_000537_jpg.rf.3a75eda720a50d51a1b894ae7f5a864b.jpg, boxes: tensor([[136., 206., 299., 255.]]), labels: tensor([19])
# Image train/2011_006101_jpg.rf.c5fb430e7abb975306e442b0aefa1f22.jpg, boxes: tensor([[ 32., 105., 236., 500.]]), labels: tensor([15])
# Image train/2011_001524_jpg.rf.05ef4925f3fd338ad6a13a94aae2c1c6.jpg, boxes: tensor([[233.,  95., 322., 225.],
#         [277., 107., 389., 269.],
#         [132.,  52., 262., 188.],
#         [140.,  54., 261., 172.],
#         [274.,   1., 382.,  51.],
#         [193.,   1., 274.,  41.],
#         [119.,   1., 185.,  39.],
#         [  2.,  14., 292., 346.],
#         [ 64.,  14.,  81.,  58.],
#         [ 77.,  14.,  87.,  55.],
#         [ 50.,  32.,  60.,  52.]]), labels: tensor([ 9,  9,  2,  2,  7,  7,  7, 14, 15, 15, 15])
# Image train/2008_002929_jpg.rf.faa9ed2a595c72810a10f8eebd94e08b.jpg, boxes: tensor([[ 96., 182., 429., 333.],
#         [263., 161., 375., 333.],
#         [124., 166., 255., 333.]]), labels: tensor([18, 15, 15])
# Image train/2010_002405_jpg.rf.64516f073b4256b264539e1db8e4ae40.jpg, boxes: tensor([[  1.,   1., 500., 374.]]), labels: tensor([15])
# Image train/2008_003813_jpg.rf.8316bbf938fd1c8829d5109af50159d1.jpg, boxes: tensor([[211.,  54., 395., 211.],
#         [  1., 168., 500., 336.],
#         [259.,  99., 375., 336.]]), labels: tensor([15,  7, 15])
# Image train/2007_007003_jpg.rf.bec53fb32ad10ae87abf728226bd225b.jpg, boxes: tensor([[188., 216., 327., 287.],
#         [  1., 242.,  83., 337.],
#         [ 38., 256., 235., 375.],
#         [196., 256., 313., 363.],
#         [396., 276., 500., 368.]]), labels: tensor([6, 7, 7, 7, 7])
# Image train/2012_002091_jpg.rf.8d943222f21dea1c8a499b4da1b927b0.jpg, boxes: tensor([[195.,  96., 311., 375.]]), labels: tensor([15])
# Image train/2011_004283_jpg.rf.9b68fa9c767feb800f9e6df7aa1722a1.jpg, boxes: tensor([[173., 158., 256., 278.],
#         [348., 156., 364., 197.]]), labels: tensor([15, 15])
# Image train/2011_004409_jpg.rf.714c37e371eeeba64bba0ac024537596.jpg, boxes: tensor([[  1.,  24., 417., 333.]]), labels: tensor([15])
# Image train/2008_001681_jpg.rf.0b0dacdce373ca50e37d56305fbc2925.jpg, boxes: tensor([[188., 244., 219., 263.],
#         [217., 251., 236., 263.],
#         [145., 249., 166., 262.],
#         [ 51., 231.,  95., 296.],
#         [106., 237., 121., 275.]]), labels: tensor([ 6,  7,  7,  7, 15])
# Image train/2009_004501_jpg.rf.d6f9c2d0473b65bb4e6a27da7b20ae4c.jpg, boxes: tensor([[179., 162., 317., 307.]]), labels: tensor([9])
# Image train/2010_000865_jpg.rf.f490e4b93cd209a79beac28a9a5eff9f.jpg, boxes: tensor([[ 62.,  92., 500., 257.],
#         [ 21., 164.,  37., 205.],
#         [ 43., 166.,  61., 208.],
#         [ 33., 169.,  45., 206.],
#         [  1., 172.,  16., 208.],
#         [ 53., 164.,  65., 205.]]), labels: tensor([19, 15, 15, 15,  7, 15])
# Image train/2010_000157_jpg.rf.f32b9ab85db34f9a5817eb0daac06a45.jpg, boxes: tensor([[  1.,  53., 500., 374.]]), labels: tensor([8])
# Image train/2009_005163_jpg.rf.bfc4f3ba1ce622ea0e2fc0e1dad23359.jpg, boxes: tensor([[ 25.,  60., 315., 486.]]), labels: tensor([9])
# Image train/2012_002356_jpg.rf.12f3114ec89e2caadf43796363759aca.jpg, boxes: tensor([[ 36.,  25., 167., 372.]]), labels: tensor([15])
# Image train/2010_002645_jpg.rf.17515f11066a09f2af9fd38e9ab2b8de.jpg, boxes: tensor([[  1.,   4., 331., 498.]]), labels: tensor([8])
# Image train/2011_006111_jpg.rf.cb1f0c596fe1fdbe12ee2d1a32c3f6c6.jpg, boxes: tensor([[178., 156., 343., 278.]]), labels: tensor([15])
# Image train/2008_007527_jpg.rf.a8919c34cfb1115910f60db7f528d074.jpg, boxes: tensor([[177., 123., 293., 226.],
#         [ 82., 219., 289., 375.]]), labels: tensor([20,  9])
# Image train/2009_004157_jpg.rf.6770ca8a5b540e7295691a23cc8cceb5.jpg, boxes: tensor([[123.,  25., 500., 331.]]), labels: tensor([8])
# Image train/2009_002531_jpg.rf.21b84cacbc17f7a514fc7ef5f93d116e.jpg, boxes: tensor([[ 48.,  88., 499., 193.]]), labels: tensor([1])
# Image train/2012_002746_jpg.rf.e2a5257c39e27f7ab5a4986f132ceb3f.jpg, boxes: tensor([[  7.,  87., 127., 347.]]), labels: tensor([15])
# Image train/2009_003219_jpg.rf.2a85c95c91960dad2bd4e9723d31c9a9.jpg, boxes: tensor([[ 18.,  76., 496., 300.]]), labels: tensor([1])
# Image train/2011_002567_jpg.rf.f5b376a76d4e0ba63740fc2f5742b748.jpg, boxes: tensor([[100., 158., 333., 194.],
#         [286., 137., 313., 179.]]), labels: tensor([ 4, 15])
# Image train/2010_004288_jpg.rf.e0b586b736ebebf5a6a02ae98e5af181.jpg, boxes: tensor([[146., 254., 188., 411.]]), labels: tensor([5])
# Image train/2009_001945_jpg.rf.153052b2247e4602b16fec08faec8519.jpg, boxes: tensor([[ 20., 156., 332., 500.],
#         [ 52., 134., 143., 179.]]), labels: tensor([7, 7])
# Image train/2008_002749_jpg.rf.0676e83187a39f733f8a31883dc2c1df.jpg, boxes: tensor([[ 74., 103., 500., 286.]]), labels: tensor([8])
# Image train/2009_002605_jpg.rf.ed76225bd7675408e032ea88684dc3ff.jpg, boxes: tensor([[ 81.,   1., 417., 480.]]), labels: tensor([12])
# Image train/2010_000172_jpg.rf.8d2a52e9e688ddc5b6869083dbc7b494.jpg, boxes: tensor([[336., 103., 420., 263.],
#         [153., 128., 287., 217.]]), labels: tensor([8, 8])
# Image train/2008_003691_jpg.rf.182a9c704568248ae73aa6ad28b3edf8.jpg, boxes: tensor([[121.,  94., 468., 304.],
#         [ 70., 185.,  87., 218.],
#         [471., 174., 500., 206.]]), labels: tensor([6, 7, 7])
# Image train/2010_006917_jpg.rf.a363f721683a6b288c16fa6ba5b40b23.jpg, boxes: tensor([[296.,   1., 500., 476.]]), labels: tensor([15])
# Image train/2010_000488_jpg.rf.cf06cce1d98843f6b2c68022cd5c56ad.jpg, boxes: tensor([[103.,   1., 500., 374.]]), labels: tensor([8])
# Image train/2009_001959_jpg.rf.51af247d5c2c1f906f8472ffad527ffb.jpg, boxes: tensor([[  9.,  89., 309., 325.]]), labels: tensor([17])
# Image train/2009_002763_jpg.rf.49d21b2c64d534c9232140d461757e96.jpg, boxes: tensor([[ 58.,  54., 419., 297.]]), labels: tensor([14])
# Image train/2008_005171_jpg.rf.410ec87279d38ec8daf0ae78470ebf8a.jpg, boxes: tensor([[142., 132., 500., 314.],
#         [350., 125., 405., 146.],
#         [ 81., 105., 122., 126.]]), labels: tensor([7, 7, 7])
# Image train/2007_004003_jpg.rf.3f0a2e6cb81e47484e261ae2d98a9258.jpg, boxes: tensor([[ 45.,  50., 472., 315.]]), labels: tensor([14])
# Image train/2010_006124_jpg.rf.d84283b71841c5744d0f3ca70bb72221.jpg, boxes: tensor([[ 51.,  52., 448., 375.]]), labels: tensor([15])
# Image train/2008_006655_jpg.rf.5a911a36ee5780ef7c9db6ac0c9deb64.jpg, boxes: tensor([[  1., 169., 426., 276.]]), labels: tensor([19])
# Image train/2008_007073_jpg.rf.0e4b873d39cb4a257b9d59ce63f89f75.jpg, boxes: tensor([[205., 137., 292., 295.],
#         [239.,  36., 351., 254.]]), labels: tensor([12, 12])
# Image train/2009_004099_jpg.rf.b67bfaa698e0dbb1e03d6d2ed9cafd3b.jpg, boxes: tensor([[182.,  88., 261., 195.],
#         [262.,   1., 500., 333.]]), labels: tensor([ 8, 18])
# Image train/2008_002728_jpg.rf.fe0143f47025d4ed44124cfacdaeceb0.jpg, boxes: tensor([[ 87.,  22., 406., 284.],
#         [202.,  37., 351., 208.]]), labels: tensor([15, 15])
# Image train/2009_004977_jpg.rf.6b67137d91cc09bacff6e5811bb2f8b9.jpg, boxes: tensor([[  1., 177., 341., 239.],
#         [354., 180., 435., 215.]]), labels: tensor([19, 19])
# Image train/2011_006561_jpg.rf.335b0f020f7e4892c9ad53d3a47d5a01.jpg, boxes: tensor([[159.,  17., 420., 288.]]), labels: tensor([15])
# Image train/2008_002359_jpg.rf.99fc4319b0abde2775d68d994f9fd76d.jpg, boxes: tensor([[ 25.,  65., 291., 346.],
#         [288.,  59., 457., 186.]]), labels: tensor([12, 12])
# Image train/2011_003482_jpg.rf.4f7fc68a4e4d21ff4150b17c645e3bda.jpg, boxes: tensor([[198.,  74., 405., 375.]]), labels: tensor([15])
# Image train/2009_002566_jpg.rf.c0b358adba518009bde5699906ab4202.jpg, boxes: tensor([[109.,  39., 429., 269.],
#         [144., 125., 193., 168.],
#         [ 28.,  48., 113., 189.]]), labels: tensor([ 6, 15,  6])
# Image train/2008_008025_jpg.rf.22f066ea1caa1d1adae6b02699bd6cb6.jpg, boxes: tensor([[ 41.,  59., 296., 156.],
#         [302., 112., 436., 164.],
#         [ 14.,  99.,  46., 112.]]), labels: tensor([1, 1, 7])
# Image train/2009_002851_jpg.rf.6ca002a274f702df67c913c4c173150b.jpg, boxes: tensor([[284., 381., 306., 445.],
#         [238., 339., 312., 354.]]), labels: tensor([15,  4])
# Image train/2010_003987_jpg.rf.60ee906eb39df5d1b145e16fee09201c.jpg, boxes: tensor([[106.,  54., 397., 355.]]), labels: tensor([12])
# Image train/2011_000163_jpg.rf.f8a7a2ba03f03fa97b6074800aa89191.jpg, boxes: tensor([[164.,  70., 335., 168.]]), labels: tensor([1])
# Image train/2011_006028_jpg.rf.e4108ebb33a759155f111703dfa690d8.jpg, boxes: tensor([[305., 192., 364., 357.]]), labels: tensor([15])
# Image train/2010_002537_jpg.rf.998eb89da383d4c3a981ecb269343025.jpg, boxes: tensor([[ 50.,  15., 142., 250.],
#         [ 54.,  54., 148., 190.],
#         [264.,  86., 325., 208.],
#         [310.,  49., 368., 209.],
#         [  1., 231., 500., 297.]]), labels: tensor([16, 16, 16, 16, 11])
# Image train/2008_004777_jpg.rf.e8b2cb702bd295cb327ddf59724652a6.jpg, boxes: tensor([[360., 235., 430., 336.]]), labels: tensor([9])
# Image train/2012_002445_jpg.rf.cc90142ba4c75ad36feef9d60970f7c1.jpg, boxes: tensor([[211.,  75., 267., 210.]]), labels: tensor([15])
# Image train/2010_001992_jpg.rf.fc6f6ba2b7b754543a3ddc49dc6978d3.jpg, boxes: tensor([[205.,  81., 364., 210.],
#         [180., 184., 321., 282.]]), labels: tensor([3, 3])
# Image train/2009_002612_jpg.rf.f21501b5931a821c46ad084682b51c40.jpg, boxes: tensor([[217., 202., 434., 362.],
#         [  1., 408., 163., 500.],
#         [ 74., 213., 178., 325.],
#         [162., 198., 229., 327.],
#         [ 44., 206., 141., 328.],
#         [110., 190., 175., 305.],
#         [ 46., 193., 129., 309.]]), labels: tensor([18, 18, 11,  9,  9,  9,  9])
# Image train/2010_006507_jpg.rf.f2b35dec2350e66f049f374ad3b40a17.jpg, boxes: tensor([[323.,  44., 500., 330.],
#         [238.,  14., 358., 280.]]), labels: tensor([15, 15])
# Image train/2012_003484_jpg.rf.f3ca6c628146d7cac492256463511190.jpg, boxes: tensor([[ 77.,  62., 151., 244.]]), labels: tensor([15])
# Image train/2011_005943_jpg.rf.b475db4257843eaf57888cf3d03102d8.jpg, boxes: tensor([[198., 186., 396., 340.],
#         [428., 182., 500., 338.]]), labels: tensor([15, 15])
# Image train/2012_000623_jpg.rf.c26bd7059fd241fdf47c4f358a3df2f8.jpg, boxes: tensor([[186.,  75., 364., 375.]]), labels: tensor([15])
# Image train/2010_005232_jpg.rf.fdafce5ae02caeb73942447568c37924.jpg, boxes: tensor([[ 14.,  45., 481., 269.]]), labels: tensor([8])
# Image train/2012_001000_jpg.rf.26f69713988cf1bc8ef55f575c8329c3.jpg, boxes: tensor([[297.,  80., 449., 338.]]), labels: tensor([15])
# Image train/2011_003294_jpg.rf.af24a3deaa450a974471a604bbd286d1.jpg, boxes: tensor([[227., 102., 293., 243.],
#         [314., 111., 367., 189.],
#         [103., 158., 130., 195.]]), labels: tensor([15, 15, 15])
# Image train/2008_004613_jpg.rf.948c7c9a6efb84ed79d781254ce276d9.jpg, boxes: tensor([[ 29.,  12., 477., 304.],
#         [477., 210., 500., 264.]]), labels: tensor([6, 7])
# Image train/2010_004423_jpg.rf.c7bb0ed1383115dbd5978916d10a65d3.jpg, boxes: tensor([[ 63., 113., 384., 214.]]), labels: tensor([1])
# Image train/2007_002914_jpg.rf.e3a4d379a7b98e6c200df8561b2e11fa.jpg, boxes: tensor([[  2., 266., 397., 375.],
#         [287.,  13., 500., 374.]]), labels: tensor([11, 15])
# Image train/2011_003050_jpg.rf.dc9c9cae828fab162151d305a59ff52b.jpg, boxes: tensor([[  1., 178., 499., 238.],
#         [248.,   1., 500., 187.],
#         [212., 138., 230., 180.],
#         [201., 143., 216., 181.],
#         [179., 134., 194., 159.],
#         [149., 138., 162., 159.],
#         [159., 133., 171., 153.],
#         [162., 141., 182., 162.]]), labels: tensor([11, 15,  5,  5,  5,  5,  5,  5])
# Image train/2008_000544_jpg.rf.0818834b7de61a8cfdf2bec97c9b7977.jpg, boxes: tensor([[227.,   1., 488., 333.]]), labels: tensor([15])
# Image train/2008_000662_jpg.rf.f21c4cb871d58308353e6af705456acb.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2012_002104_jpg.rf.c92c6f59d1e22b1808d25b23b9f4406f.jpg, boxes: tensor([[  1.,   1., 500., 349.]]), labels: tensor([15])
# Image train/2011_005170_jpg.rf.31f3f14dd93f6e814e988451422f85a8.jpg, boxes: tensor([[208., 127., 250., 231.]]), labels: tensor([15])
# Image train/2008_005758_jpg.rf.c4634460e68e7614bb263e82339e1959.jpg, boxes: tensor([[222.,   1., 363., 500.],
#         [  1.,   1., 130., 500.]]), labels: tensor([5, 5])
# Skipping batch with empty targets: [0, 1, 1, 2]
# Image train/2012_001012_jpg.rf.efb57d0b52e85399360fd1c16f596557.jpg, boxes: tensor([[  1.,  79., 101., 322.]]), labels: tensor([15])
# Image train/2008_003263_jpg.rf.0c78f6d72cb25100d4e18761efc7c2b9.jpg, boxes: tensor([[113.,  96., 406., 272.],
#         [  1.,  72., 173., 254.],
#         [487., 183., 496., 211.],
#         [267., 136., 300., 162.]]), labels: tensor([19, 19, 15, 15])
# Image train/2009_003018_jpg.rf.b9f488155969c884c331cfe86ed5bf25.jpg, boxes: tensor([[ 26.,  61., 449., 280.]]), labels: tensor([6])
# Image train/2008_006969_jpg.rf.8d75270988981fd77e88f879d148cbfc.jpg, boxes: tensor([[ 78., 163., 487., 333.],
#         [130., 129., 310., 333.],
#         [ 59., 110., 156., 333.],
#         [  4.,  96., 106., 310.],
#         [ 74.,  82., 176., 179.],
#         [144.,  80., 200., 171.],
#         [201.,  76., 298., 194.],
#         [322.,  99., 451., 239.],
#         [391., 120., 500., 333.],
#         [368., 188., 394., 273.],
#         [250., 149., 272., 211.]]), labels: tensor([11, 15, 15, 15, 15, 15, 15, 15, 15,  5,  5])
# Image train/2012_003133_jpg.rf.4e2fd4dbc0f221d52f075c9c5cc7a3c3.jpg, boxes: tensor([[ 92.,  72., 250., 165.]]), labels: tensor([15])
# Image train/2011_006217_jpg.rf.a3188d1e6f892bd378f154dd3879b78d.jpg, boxes: tensor([[108., 116., 489., 375.]]), labels: tensor([15])
# Image train/2010_002830_jpg.rf.321a3a0ea164786d291cbb0aab43dd2b.jpg, boxes: tensor([[ 21.,  81., 272., 428.],
#         [  1., 271.,  93., 426.],
#         [250., 208., 375., 467.],
#         [  1., 259., 299., 500.]]), labels: tensor([16, 16,  9, 11])
# Image train/2011_001642_jpg.rf.366c617802a120aae9482a9cf6042d1b.jpg, boxes: tensor([[136.,  11., 382., 341.]]), labels: tensor([12])
# Image train/2011_006514_jpg.rf.bcec808ec631cda858aabfb059fe6579.jpg, boxes: tensor([[ 17.,   1., 500., 334.]]), labels: tensor([15])
# Image train/2008_005084_jpg.rf.a0e414ea8df27ce421a3b3150187c099.jpg, boxes: tensor([[ 46.,  80., 434., 353.]]), labels: tensor([12])
# Image train/2007_005425_jpg.rf.3c916c3022c497a9d8b6dd2f797f9912.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2009_001407_jpg.rf.b2d145db9f320de30c67dd7630e235df.jpg, boxes: tensor([[ 41.,  18., 304., 415.],
#         [262., 325., 342., 378.],
#         [258., 310., 313., 372.]]), labels: tensor([ 4, 15, 15])
# Skipping batch with empty targets: [1, 1, 0, 3]
# Image train/2011_002944_jpg.rf.cf1463579230befccf79c7a6f19ab717.jpg, boxes: tensor([[232.,   1., 499., 375.],
#         [ 59., 102.,  96., 212.]]), labels: tensor([ 6, 15])
# Image train/2008_004112_jpg.rf.779095a0925019f92b285918f5424f95.jpg, boxes: tensor([[ 56., 103., 441., 268.]]), labels: tensor([7])
# Image train/2008_007194_jpg.rf.b50ef95505830a9941b83a51782ec79d.jpg, boxes: tensor([[ 41.,  89., 171., 312.],
#         [209.,  92., 337., 318.],
#         [355.,  88., 489., 304.]]), labels: tensor([9, 9, 9])
# Image train/2009_003383_jpg.rf.851f1ba748cff0d7a6231aa141d903d7.jpg, boxes: tensor([[ 25.,  22., 465., 315.],
#         [441., 167., 465., 263.]]), labels: tensor([ 6, 15])
# Image train/2010_002424_jpg.rf.66a9d9183c956c546a557a51255ba40b.jpg, boxes: tensor([[407.,  14., 500.,  66.],
#         [255.,  32., 500., 126.],
#         [ 10.,  43., 474., 266.],
#         [378.,   1., 412.,  54.],
#         [293.,  13., 325.,  27.],
#         [320.,  14., 339.,  24.]]), labels: tensor([ 7,  7,  7, 15,  7,  7])
# Image train/2009_001835_jpg.rf.3e2a8ff97018072bfaace1a1c3cffa96.jpg, boxes: tensor([[ 92.,   1., 375., 500.]]), labels: tensor([8])
# Image train/2011_004922_jpg.rf.948de21d8c46201861880c5b47eac9cc.jpg, boxes: tensor([[182.,  35., 372., 235.]]), labels: tensor([15])
# Image train/2008_005818_jpg.rf.d3c1dc865571b3a43351bde6b40705c5.jpg, boxes: tensor([[315.,  28., 465., 315.],
#         [302., 102., 365., 272.],
#         [188., 117., 314., 287.],
#         [109.,  91., 226., 287.],
#         [  1., 127.,  58., 272.]]), labels: tensor([13, 13, 13, 13, 13])
# Image train/2008_001536_jpg.rf.cfa62bbca7c7a28741e296f519e41e82.jpg, boxes: tensor([[204., 108., 343., 279.],
#         [ 64.,  23., 256., 333.],
#         [249.,  19., 469., 333.]]), labels: tensor([15, 15, 15])
# Image train/2009_004279_jpg.rf.d989f748ad04872a030b66777cf52a0e.jpg, boxes: tensor([[ 86.,  35., 224., 256.],
#         [ 67., 116., 322., 334.],
#         [186.,  57., 496., 334.]]), labels: tensor([13, 15, 15])
# Image train/2012_000150_jpg.rf.fbc009255fc4321d938321c0865906fd.jpg, boxes: tensor([[212., 140., 303., 307.]]), labels: tensor([15])
# Image train/2012_002393_jpg.rf.034f15220b7663d2348173e35baa1afe.jpg, boxes: tensor([[ 74.,  84., 424., 375.]]), labels: tensor([15])
# Image train/2011_000785_jpg.rf.a049764eb027afca3da819307bca067b.jpg, boxes: tensor([[234.,  81., 292., 103.],
#         [125.,  97., 286., 500.],
#         [ 75., 200., 332., 475.]]), labels: tensor([ 7, 15, 15])
# Image train/2010_004757_jpg.rf.4d454222b5fe2c6f90f77f6f12e28f91.jpg, boxes: tensor([[ 78.,  24., 397., 350.],
#         [  1.,   1., 500., 146.]]), labels: tensor([16, 18])
# Image train/2009_003690_jpg.rf.9af32b80bcf3ee2682b90ce8cbc162f1.jpg, boxes: tensor([[  1.,  79., 500., 400.],
#         [206.,   1., 414.,  92.]]), labels: tensor([11, 15])
# Image train/2010_001780_jpg.rf.6bafe39232ddce8f55707802a32bf424.jpg, boxes: tensor([[148., 147., 324., 299.]]), labels: tensor([20])
# Image train/2010_004419_jpg.rf.db5cc50a1849996858582db4721b83fa.jpg, boxes: tensor([[  1., 144., 486., 318.]]), labels: tensor([1])
# Image train/2010_005782_jpg.rf.ee4f92f832d59ecc4660fe493603fe66.jpg, boxes: tensor([[ 11.,  76., 459., 331.]]), labels: tensor([2])
# Image train/2009_000206_jpg.rf.47bb3b7cf4834848d56c11a6e5ba8125.jpg, boxes: tensor([[138.,  87., 286., 367.]]), labels: tensor([3])
# Image train/2007_003565_jpg.rf.402701e5cf182af53ed99b4001a2361f.jpg, boxes: tensor([[280., 218., 500., 317.]]), labels: tensor([3])
# Image train/2010_000213_jpg.rf.e43d5b4c8ae1acd1211e8182004d76d5.jpg, boxes: tensor([[ 22.,   1., 488., 404.]]), labels: tensor([5])
# Image train/2012_003138_jpg.rf.d3e1b7ddb8399260890bbc9889475c8c.jpg, boxes: tensor([[ 13.,  40., 213., 375.],
#         [195.,   1., 500., 375.]]), labels: tensor([15, 15])
# Image train/2011_004262_jpg.rf.ea6e8f23cea9656d2d07acbbc3ac4268.jpg, boxes: tensor([[104.,  68., 287., 500.]]), labels: tensor([15])
# Image train/2009_003867_jpg.rf.1add85ab16d56efbf2a29fa4c5b87f0e.jpg, boxes: tensor([[  1.,   1., 375., 345.]]), labels: tensor([8])
# Image train/2008_007120_jpg.rf.1cc808f99d989ae7447d8d2ea1b737b7.jpg, boxes: tensor([[253.,  36., 368., 327.]]), labels: tensor([3])
# Image train/2008_000670_jpg.rf.c653ff0cf90b33a88dd2a0628ef7d8bd.jpg, boxes: tensor([[ 67.,  76., 271., 168.],
#         [  1.,   1., 384., 256.]]), labels: tensor([ 8, 18])
# Image train/2009_004442_jpg.rf.eaba3687a4941daaec2ff65a5f4d5360.jpg, boxes: tensor([[ 41.,  26., 355., 272.],
#         [  8., 156., 333., 463.]]), labels: tensor([8, 8])
# Image train/2008_004921_jpg.rf.de30f1ed5481f6bc84cb5f6b5d4b4783.jpg, boxes: tensor([[  1.,   1., 144., 314.],
#         [142., 230., 259., 318.],
#         [244.,   1., 500., 331.],
#         [240., 156., 258., 253.],
#         [172., 191., 183., 233.],
#         [185., 205., 194., 233.],
#         [370., 213., 395., 252.],
#         [215., 235., 237., 283.],
#         [175., 235., 194., 283.],
#         [  1., 252.,  22., 281.]]), labels: tensor([ 4,  4,  4,  4,  4,  4,  4, 15, 15, 15])
# Image train/2008_005421_jpg.rf.58b8eadc60ff3ac569c53822f6eced36.jpg, boxes: tensor([[  8., 100., 321., 302.]]), labels: tensor([8])
# Image train/2007_004189_jpg.rf.7bb42758e03ede026f8f220aadadde21.jpg, boxes: tensor([[171.,  57., 344., 280.]]), labels: tensor([12])
# Image train/2012_000762_jpg.rf.ad472f55fbaea6466cefad614fc71458.jpg, boxes: tensor([[206.,  93., 332., 388.]]), labels: tensor([15])
# Image train/2011_000213_jpg.rf.ee98c6c5f3ffa32f9fd21091bce441b3.jpg, boxes: tensor([[ 11.,  16., 249., 382.],
#         [  1.,  72., 268., 500.]]), labels: tensor([ 9, 15])
# Image train/2009_004032_jpg.rf.b255f1ddfc8bce65e4a6f6715fcc6e04.jpg, boxes: tensor([[ 27., 219., 459., 375.],
#         [342.,  51., 500., 372.],
#         [  8.,  92., 114., 310.],
#         [216.,  85., 341., 233.],
#         [277.,   2., 300.,  31.],
#         [160.,   1., 190.,  31.],
#         [ 91.,  81., 131., 145.],
#         [123.,  82., 136., 149.],
#         [ 23.,  56.,  69.,  93.]]), labels: tensor([11, 15, 15, 15, 16, 16,  9,  9, 15])
# Image train/2009_004072_jpg.rf.1ea4fc9630cae8a99018080c39c4489d.jpg, boxes: tensor([[ 59.,  30., 500., 375.],
#         [200., 156., 266., 242.]]), labels: tensor([ 6, 15])
# Image train/2008_001640_jpg.rf.7b674d79b67adb9b3f78dda86ca539f4.jpg, boxes: tensor([[159.,   5., 465., 200.]]), labels: tensor([8])
# Image train/2010_000035_jpg.rf.0ecba10aabdd8d56a54212b953b7a863.jpg, boxes: tensor([[301.,   1., 500., 163.],
#         [  1.,   1., 134., 160.],
#         [ 14.,   6., 486., 317.]]), labels: tensor([ 7,  7, 14])
# Image train/2008_001504_jpg.rf.a40a7cda80b628c5ecd856e4750b6e38.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2008_003829_jpg.rf.19e3ea67df13859b8d0c9bd4e8a8c131.jpg, boxes: tensor([[  1., 108.,  54., 143.],
#         [  1., 107.,  16., 165.],
#         [ 21., 105.,  44., 164.],
#         [489., 106., 500., 142.]]), labels: tensor([ 7, 15, 15,  7])
# Image train/2009_000502_jpg.rf.f89cbe62c14a02d9924bb7d9e83832c1.jpg, boxes: tensor([[  1.,  40., 500., 375.],
#         [239.,   4., 296., 187.]]), labels: tensor([11,  5])
# Image train/2011_004312_jpg.rf.8e18c9cacd0d1977754da1e077cda49c.jpg, boxes: tensor([[406., 171., 446., 283.],
#         [456., 153., 482., 211.],
#         [310., 143., 335., 205.],
#         [244., 112., 297., 206.]]), labels: tensor([15, 15, 15, 15])
# Skipping batch with empty targets: [0, 4, 2, 4]
# Image train/2007_007815_jpg.rf.80bb77c3935930467f4e8ac5cfa94f12.jpg, boxes: tensor([[ 31.,  45., 401., 286.],
#         [238.,  44., 309., 126.],
#         [135.,  55., 210., 130.]]), labels: tensor([ 7, 15, 15])
# Image train/2008_001765_jpg.rf.30ea6e64d2d8cd46962500637ef618f6.jpg, boxes: tensor([[ 97., 151., 252., 500.],
#         [238., 161., 320., 500.],
#         [291., 162., 375., 500.],
#         [ 29., 204.,  73., 315.],
#         [ 83., 199., 152., 466.],
#         [  1., 211.,  27., 269.],
#         [ 72., 227.,  92., 273.]]), labels: tensor([15, 15, 15, 15, 15, 15, 15])
# Image train/2010_006512_jpg.rf.567e6ae5fbb52ebe8a5a2d2c9a9b49bd.jpg, boxes: tensor([[ 48.,  71., 249., 293.]]), labels: tensor([15])
# Image train/2008_001928_jpg.rf.7ff4a84aee4700f3e8716011a3a10a49.jpg, boxes: tensor([[132., 171., 302., 375.],
#         [100., 134., 365., 369.],
#         [ 87., 103., 128., 153.],
#         [ 88., 102., 150., 167.],
#         [110., 128., 196., 198.],
#         [170., 135., 226., 208.],
#         [  1., 141., 127., 363.],
#         [  1., 127.,  62., 192.],
#         [  1., 103.,  27., 170.],
#         [  1., 248.,  93., 375.],
#         [ 79., 322., 124., 375.],
#         [269., 255., 500., 375.],
#         [398., 238., 420., 278.],
#         [ 62., 155., 184., 333.]]), labels: tensor([15, 15, 15, 15, 15, 15, 15, 15, 15,  9,  9, 11,  5, 11])
# Image train/2008_007997_jpg.rf.6996d37c78e69110ddd3673d27112592.jpg, boxes: tensor([[104., 104., 276., 214.],
#         [  1., 184.,  64., 224.],
#         [475.,  28., 500.,  56.],
#         [473.,   1., 496.,  14.]]), labels: tensor([6, 7, 7, 7])
# Image train/2010_004838_jpg.rf.1824b1d106491785a80d8f4ddd54d1cf.jpg, boxes: tensor([[  1.,   1., 443., 375.],
#         [216., 109., 441., 347.]]), labels: tensor([15,  5])
# Image train/2009_000439_jpg.rf.39cabea312b02f329c327fffeb65a10d.jpg, boxes: tensor([[330., 161., 360., 194.],
#         [259., 170., 341., 279.],
#         [ 57., 195., 108., 288.]]), labels: tensor([16,  9, 20])
# Image train/2011_003094_jpg.rf.146b0f383fa043ce847badb7f53fc8c4.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Skipping batch with empty targets: [4, 2, 3, 0]
# Image train/2008_000510_jpg.rf.6b8fd6f160d48f6caf8717278d72c8b0.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2007_007098_jpg.rf.5af9bcd73525dfab73e689d3c92e2f89.jpg, boxes: tensor([[ 17.,  65., 201., 351.],
#         [167., 162., 499., 465.]]), labels: tensor([8, 8])
# Image train/2008_008147_jpg.rf.e8e3d67a87b5257a756f3f6e30060011.jpg, boxes: tensor([[311., 210., 427., 329.],
#         [  1.,  56., 452., 348.],
#         [  1.,   1., 265., 304.],
#         [  2.,  19., 132., 166.]]), labels: tensor([13, 13, 15, 15])
# Image train/2011_005970_jpg.rf.3b4c06d58173d5d8d010f7daf0c034e4.jpg, boxes: tensor([[225., 280., 243., 323.],
#         [240., 280., 257., 322.]]), labels: tensor([15, 15])
# Skipping batch with empty targets: [0, 2, 4, 2]
# Image train/2011_000088_jpg.rf.3dee2c349fabeaac8036c94bb691e71e.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2008_002244_jpg.rf.5a3b6fbced26e8107eb1b4057c236ca5.jpg, boxes: tensor([[130., 295., 155., 359.],
#         [176., 284., 206., 356.],
#         [226., 286., 256., 355.],
#         [111., 290., 135., 360.],
#         [205., 290., 231., 356.],
#         [236., 241., 248., 265.]]), labels: tensor([15, 15, 15, 15, 15, 15])
# Image train/2012_002617_jpg.rf.6720a3adb70b68efd36da201f5113319.jpg, boxes: tensor([[121.,  63., 215., 266.],
#         [192.,  30., 236., 144.]]), labels: tensor([15, 15])
# Image train/2011_002558_jpg.rf.b0372fc19858aad0ce461ac68b1814d9.jpg, boxes: tensor([[296., 212., 358., 297.],
#         [329., 273., 338., 289.],
#         [303., 280., 310., 291.]]), labels: tensor([ 4, 15, 15])
# Skipping batch with empty targets: [0, 6, 2, 3]
# Image train/2008_001140_jpg.rf.0e1d82d89255bbf8c63c73f4d19516cc.jpg, boxes: tensor([[ 62., 280.,  93., 364.],
#         [263., 280., 312., 353.]]), labels: tensor([15, 15])
# Image train/2009_002144_jpg.rf.bc4d741e3a9ae490a2ef224a55047020.jpg, boxes: tensor([[ 74.,  92., 467., 300.]]), labels: tensor([19])
# Image train/2009_001965_jpg.rf.69142bc761adf1583fc725b7a23a7d4b.jpg, boxes: tensor([[ 19.,  24., 436., 336.]]), labels: tensor([15])
# Image train/2008_008203_jpg.rf.6dd18a572bea6ee4d0bab7687ba9dcc8.jpg, boxes: tensor([[ 28., 187.,  57., 225.],
#         [ 95.,   1., 500., 375.]]), labels: tensor([16, 19])
# Image train/2008_004758_jpg.rf.bbe7c814743b9075dd2af7a2fe81e009.jpg, boxes: tensor([[  8.,  45., 372., 353.]]), labels: tensor([2])
# Image train/2011_006044_jpg.rf.9cbe18e3b394d4d25986f47f032bb6c3.jpg, boxes: tensor([[205., 123., 371., 497.]]), labels: tensor([15])
# Image train/2008_004725_jpg.rf.ff8aa41206efc85e7002216b18ee87d7.jpg, boxes: tensor([[ 26., 165., 382., 494.]]), labels: tensor([6])
# Image train/2010_002767_jpg.rf.cab3ddce638f8a7bdf1ac323532c4952.jpg, boxes: tensor([[  1., 351., 331., 500.],
#         [  4.,  81., 333., 500.]]), labels: tensor([ 2, 15])
# Image train/2010_000347_jpg.rf.6f84fa16ff6fe3652d75be21efe57127.jpg, boxes: tensor([[  1.,  58., 500., 375.]]), labels: tensor([8])
# Image train/2008_006341_jpg.rf.a2126c96f2e099b0fa0a7b0d2dc834b2.jpg, boxes: tensor([[ 57.,   7., 384., 199.],
#         [155., 121., 450., 370.]]), labels: tensor([ 8, 15])
# Image train/2008_005507_jpg.rf.3cbf7d4c41ababf17d67d92942379c97.jpg, boxes: tensor([[ 76.,  93., 392., 393.]]), labels: tensor([3])
# Image train/2012_000823_jpg.rf.9e64ba4e6938f260b23adc5487b49324.jpg, boxes: tensor([[ 84.,  73., 436., 333.]]), labels: tensor([15])
# Image train/2010_000254_jpg.rf.07f181c149e8ba8bc893472ea4cee2b5.jpg, boxes: tensor([[130., 136., 339., 290.]]), labels: tensor([2])
# Image train/2011_004935_jpg.rf.9d1d795e47e6b389e4cecfe3c89410b6.jpg, boxes: tensor([[ 32.,  12., 128., 293.]]), labels: tensor([15])
# Image train/2009_004225_jpg.rf.b9fb75144c68c5708e11d3ac260c42d1.jpg, boxes: tensor([[  1.,   1., 313., 375.],
#         [222.,   1., 500., 375.]]), labels: tensor([8, 8])
# Image train/2009_001764_jpg.rf.054a91ced72afa1d079ce72ccfbb662a.jpg, boxes: tensor([[129., 164., 265., 385.],
#         [118.,  81., 283., 348.],
#         [173.,  58., 200., 135.]]), labels: tensor([14, 15, 14])
# Image train/2008_005735_jpg.rf.7ff7661ae0a65e701f39e6dc7bada5b3.jpg, boxes: tensor([[ 43.,  32., 290., 455.]]), labels: tensor([8])
# Image train/2012_002020_jpg.rf.20cbc25543b845e131bccf6d709e1665.jpg, boxes: tensor([[303., 107., 376., 283.]]), labels: tensor([15])
# Image train/2010_004856_jpg.rf.308c88af71113abf2d69e0bbde205daa.jpg, boxes: tensor([[ 55.,  42., 500., 357.]]), labels: tensor([13])
# Image train/2012_001047_jpg.rf.2ebdb4134dd8d18b7779ed0987d4be72.jpg, boxes: tensor([[ 88.,  46., 371., 375.]]), labels: tensor([15])
# Image train/2012_000862_jpg.rf.4d7c32c8ecdc6e8ca44edb7636779cca.jpg, boxes: tensor([[187., 122., 301., 375.]]), labels: tensor([15])
# Image train/2009_002626_jpg.rf.2f95705ef7ba5256a80712a87101b982.jpg, boxes: tensor([[  1., 171.,  73., 275.]]), labels: tensor([6])
# Image train/2010_006204_jpg.rf.2968d7d3f16a899e27aa1d0e4932e34c.jpg, boxes: tensor([[  1.,  25., 222., 471.]]), labels: tensor([15])
# Image train/2008_007025_jpg.rf.acebb616741220dad8d91e07afda3754.jpg, boxes: tensor([[212., 128., 470., 305.],
#         [122., 107., 393., 291.]]), labels: tensor([10, 10])
# Image train/2009_002837_jpg.rf.8d44775e40c4e30cfac99fd0825116c1.jpg, boxes: tensor([[ 68.,   1., 500., 361.]]), labels: tensor([8])
# Image train/2010_001054_jpg.rf.149135af6c29d9727929efc20518292a.jpg, boxes: tensor([[ 73.,  15., 492., 340.]]), labels: tensor([8])
# Image train/2012_000335_jpg.rf.ae5ab364e054fce8f9b2c0082745a51a.jpg, boxes: tensor([[197.,   9., 495., 399.]]), labels: tensor([15])
# Image train/2009_000923_jpg.rf.6fde0a5d8d7bf0445cd276bbf93c4edb.jpg, boxes: tensor([[124., 143., 333., 500.]]), labels: tensor([12])
# Image train/2010_005684_jpg.rf.2d37f415bc2cbab28d37963c1a4acf58.jpg, boxes: tensor([[115.,  85., 466., 326.],
#         [200.,  12., 332., 272.]]), labels: tensor([14, 15])
# Image train/2010_000342_jpg.rf.e365f6941cb06f95347d90e2e8cd56a5.jpg, boxes: tensor([[ 55.,  37., 354., 360.]]), labels: tensor([2])
# Image train/2009_003422_jpg.rf.3ef91a2e606624e9ad6cc8a83e77d4f7.jpg, boxes: tensor([[ 28.,  12., 482., 303.],
#         [325.,  64., 356.,  94.],
#         [378.,  58., 425.,  91.]]), labels: tensor([ 6, 15, 15])
# Image train/2009_003056_jpg.rf.213410e8a09fb73d0b5c115f0646730a.jpg, boxes: tensor([[ 16.,  21., 296., 219.]]), labels: tensor([8])
# Image train/2009_004406_jpg.rf.66dacdbf0ab9466deafcabc39d767897.jpg, boxes: tensor([[ 42., 128., 360., 218.],
#         [336., 176., 357., 209.],
#         [433., 167., 456., 194.],
#         [ 66., 203., 100., 235.]]), labels: tensor([19, 15, 15, 15])
# Image train/2009_004662_jpg.rf.993d116abcd5231041ed71f06425c85e.jpg, boxes: tensor([[  1.,  86., 133., 220.],
#         [ 32., 121., 249., 289.],
#         [ 32.,  72., 367., 283.]]), labels: tensor([13, 13, 13])
# Image train/2007_002539_jpg.rf.46d6a2442ac42755530b925839cc0cb5.jpg, boxes: tensor([[  1.,   1., 500., 333.],
#         [198., 105., 307., 333.]]), labels: tensor([ 6, 15])
# Image train/2007_001960_jpg.rf.1a6760f9332bc2d8feb33b2edcaaa7cd.jpg, boxes: tensor([[108., 138., 264., 332.]]), labels: tensor([13])
# Image train/2011_006099_jpg.rf.dd106b8097a6fe06893a6ecf8c8795e0.jpg, boxes: tensor([[161., 160., 229., 429.]]), labels: tensor([15])
# Image train/2011_005335_jpg.rf.2ed153032e3b2b981270860c0038cd5b.jpg, boxes: tensor([[209.,  43., 272., 196.]]), labels: tensor([15])
# Image train/2011_004096_jpg.rf.68df6dc2b289729074682a9dc84a2233.jpg, boxes: tensor([[190., 126., 254., 195.]]), labels: tensor([15])
# Image train/2008_003488_jpg.rf.7ffa6e8c735167dfa3eeecad9c91757e.jpg, boxes: tensor([[183.,  53., 270., 355.],
#         [261.,  44., 348., 374.]]), labels: tensor([15, 15])
# Image train/2011_004324_jpg.rf.3a73876faf2bbb848f1b4ff602e4f6d8.jpg, boxes: tensor([[ 56., 250., 125., 500.],
#         [ 95., 183., 190., 477.],
#         [216., 179., 291., 485.]]), labels: tensor([15, 15, 15])
# Image train/2011_002730_jpg.rf.44692811b1962708546079fdeceb1763.jpg, boxes: tensor([[186., 158., 301., 259.],
#         [219., 143., 254., 222.]]), labels: tensor([13, 15])
# Image train/2012_001858_jpg.rf.89633b2dff99d69da6bdfa30e6d1af52.jpg, boxes: tensor([[ 70., 210., 156., 438.]]), labels: tensor([15])
# Image train/2008_003005_jpg.rf.c7ec71c4f621c57f36d6590a0a732b35.jpg, boxes: tensor([[ 23.,   1., 500., 279.]]), labels: tensor([7])
# Image train/2011_004869_jpg.rf.378226e78b174e8d92b095131625ddf4.jpg, boxes: tensor([[313., 122., 373., 276.]]), labels: tensor([15])
# Image train/2012_001030_jpg.rf.b46c1668e51f9ce6769223bda37d7dff.jpg, boxes: tensor([[333., 131., 375., 204.],
#         [358., 136., 394., 199.]]), labels: tensor([15, 15])
# Image train/2010_003768_jpg.rf.be433c744267d157196f5c500f372e5f.jpg, boxes: tensor([[152., 163., 334., 208.],
#         [  1.,  76.,  40., 100.]]), labels: tensor([7, 7])
# Image train/2007_005405_jpg.rf.3409a9b0cc4f0ea91ae89fea70f6b600.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Skipping batch with empty targets: [1, 2, 2, 0]
# Image train/2011_004724_jpg.rf.65690efd701cead1c8d7a47168c66085.jpg, boxes: tensor([[193.,  57., 266., 221.]]), labels: tensor([15])
# Image train/2011_001047_jpg.rf.d99b342059cf5e23af941a4d3192f537.jpg, boxes: tensor([[206., 101., 321., 318.],
#         [310., 121., 422., 258.],
#         [453., 124., 496., 268.]]), labels: tensor([10, 10, 10])
# Image train/2010_002965_jpg.rf.00e5f5dbfee0671ef94192dad5903561.jpg, boxes: tensor([[171.,  65., 500., 303.],
#         [ 72., 130., 187., 227.]]), labels: tensor([8, 8])
# Image train/2008_003748_jpg.rf.50617a10d868d1632c6c6980fab91ad4.jpg, boxes: tensor([[171., 155., 227., 309.],
#         [ 75., 156., 147., 309.],
#         [110., 179., 148., 249.],
# ...
#         [ 60.,  27., 109.,  96.],
#         [252.,  97., 284., 131.],
#         [241.,  48., 325., 129.],
#         [128., 195., 212., 390.],
#         [246.,  34., 270.,  56.],
#         [280.,  35., 303.,  59.],
#         [317.,  38., 339.,  60.],
#         [313.,  50., 335.,  96.],
#         [ 54.,   9.,  71.,  37.],
#         [ 37.,  20.,  67.,  79.],
#         [131.,  34., 153.,  81.],
#         [158.,  35., 176.,  59.]]), labels: tensor([16, 16, 16, 16, 15, 15, 15, 15,  9, 15,  9,  9,  9])
# Image train/2010_004789_jpg.rf.f738842817e9185bf4659b79a3bb0487.jpg, boxes: tensor([[ 78.,  69., 357., 327.],
#         [110.,  72., 162.,  94.],
#         [441.,  25., 472.,  55.]]), labels: tensor([10, 10, 10])
# Image train/2012_000003_jpg.rf.df8d64c9e1823b0d9621a18693456203.jpg, boxes: tensor([[151., 103., 389., 356.]]), labels: tensor([15])
# Image train/2009_004768_jpg.rf.47999be0478eb0cf88e11c56cedc30f1.jpg, boxes: tensor([[ 86.,  98., 500., 426.]]), labels: tensor([17])
# Image train/2010_001994_jpg.rf.adc3c121a38eb8af87c22e6359b6e119.jpg, boxes: tensor([[ 81.,   9., 277., 408.]]), labels: tensor([8])
# Image train/2008_003983_jpg.rf.04d0f0e37b1f154e95c0776add240f56.jpg, boxes: tensor([[  1.,  39., 336., 375.],
#         [154., 205., 331., 375.],
#         [221., 101., 500., 375.]]), labels: tensor([15, 15, 15])
# Image train/2009_003173_jpg.rf.8a7298b1835b08029867a1f22b3ec03d.jpg, boxes: tensor([[238., 220., 317., 269.],
#         [ 80., 216., 126., 266.]]), labels: tensor([10, 10])
# Image train/2011_006184_jpg.rf.4dbc8d1aefdca6cb32a86eb6b39b34ad.jpg, boxes: tensor([[ 38.,  22., 195., 384.]]), labels: tensor([15])
# Image train/2011_005909_jpg.rf.d67ff07d79d8de727b3366c239f0f579.jpg, boxes: tensor([[213., 105., 426., 375.]]), labels: tensor([15])
# Image train/2011_000454_jpg.rf.76de4e256fecdcf00b9f01f421968982.jpg, boxes: tensor([[357., 180., 429., 239.],
#         [184., 196., 242., 241.],
#         [131., 216., 200., 280.]]), labels: tensor([17, 17, 17])
# Image train/2012_000637_jpg.rf.785caa169b0a5a1e6073f44604355d2e.jpg, boxes: tensor([[288., 149., 319., 221.]]), labels: tensor([15])
# Image train/2008_003965_jpg.rf.d523b6252b6d5da9b5c79aa4ffa3201c.jpg, boxes: tensor([[124.,  64., 474., 375.],
#         [  1.,  14., 153., 282.],
#         [354.,  59., 456., 217.],
#         [ 73.,  73., 200., 324.]]), labels: tensor([15, 15, 15, 15])
# Image train/2008_000607_jpg.rf.7e492455fe1607b292dfa4ff3995695c.jpg, boxes: tensor([[148.,  23., 500., 333.]]), labels: tensor([15])
# Image train/2010_000541_jpg.rf.e2032bba7a41b9ae779dbf0b320653b5.jpg, boxes: tensor([[ 37.,  17., 394., 323.]]), labels: tensor([1])
# Image train/2012_002614_jpg.rf.248328e3e4fcf2bea42a3a4182280254.jpg, boxes: tensor([[ 94.,   9., 500., 334.]]), labels: tensor([15])
# Image train/2011_002556_jpg.rf.60c6066e6246f36ed653e1653aa96b08.jpg, boxes: tensor([[233., 254., 500., 375.],
#         [ 50., 121., 139., 375.],
#         [155., 176., 244., 375.],
#         [405., 215., 500., 340.],
#         [391., 243., 442., 301.],
#         [325., 232., 381., 293.],
#         [315., 224., 355., 276.],
#         [311., 145., 371., 269.],
#         [266., 209., 306., 260.],
#         [259., 186., 315., 261.],
#         [233., 194., 271., 248.],
#         [214., 191., 249., 239.],
#         [201., 177., 223., 215.],
#         [ 97., 146., 132., 203.],
#         [ 48., 167.,  73., 266.],
#         [  1., 179.,  46., 221.],
#         [  1., 194.,  20., 243.],
#         [  1., 274.,  51., 375.],
#         [  1., 216.,  53., 278.],
#         [227., 238., 263., 336.]]), labels: tensor([11, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 11,
#         11, 11])
# Image train/2010_006062_jpg.rf.d3c2eee61629758c60e368086b4ddd01.jpg, boxes: tensor([[331., 202., 455., 300.],
#         [219., 204., 340., 302.],
#         [ 60., 191., 152., 291.]]), labels: tensor([13, 13, 13])
# Image train/2010_004191_jpg.rf.66a878d83886922152c7d15b46ab6ee9.jpg, boxes: tensor([[  1., 229.,  70., 445.],
#         [256., 187., 298., 250.],
#         [105., 108., 220., 412.]]), labels: tensor([14, 14, 15])
# Image train/2008_000970_jpg.rf.de8ce02c22f50029a77ba7a71e86c9f8.jpg, boxes: tensor([[ 43., 197., 121., 393.],
#         [106., 194., 194., 391.],
#         [168., 196., 245., 381.],
#         [224., 199., 295., 385.],
#         [292., 200., 375., 383.],
#         [360., 201., 440., 382.]]), labels: tensor([15, 15, 15, 15, 15, 15])
# Image train/2008_002725_jpg.rf.de9319be2a130aaccbe753b3ed150445.jpg, boxes: tensor([[201., 117., 317., 333.],
#         [  1., 183., 117., 333.]]), labels: tensor([15, 15])
# Image train/2008_002384_jpg.rf.9f93c6ceeaea6e066ac26d21385f5939.jpg, boxes: tensor([[177., 161., 337., 375.],
#         [ 40., 232., 147., 375.],
#         [208., 271., 479., 375.],
#         [368., 224., 500., 366.]]), labels: tensor([15,  9, 11,  2])
# Image train/2011_004786_jpg.rf.c1f41f914fdd346dd08374872419501a.jpg, boxes: tensor([[232.,  84., 320., 351.]]), labels: tensor([15])
# Image train/2010_001094_jpg.rf.1b76d9e1e36aa0a5be79f40f899785b4.jpg, boxes: tensor([[155.,  89., 298., 234.],
#         [137., 147., 185., 204.],
#         [268.,  20., 347., 160.],
#         [138.,  13., 305., 220.]]), labels: tensor([12,  5,  9, 15])
# Image train/2008_005035_jpg.rf.366fed827fbf3c6bc62f3c8d288bdabd.jpg, boxes: tensor([[ 44., 140., 375., 435.],
#         [ 52., 105., 243., 500.],
#         [127.,   1., 251., 224.]]), labels: tensor([18, 15, 15])
# Image train/2009_003802_jpg.rf.f196216b4eb9dd60bc060edbf5af158d.jpg, boxes: tensor([[ 83.,  17., 334., 357.],
#         [401.,  57., 500., 375.],
#         [ 87.,   7., 193.,  87.]]), labels: tensor([14,  7,  2])
# Image train/2012_003581_jpg.rf.9304b72df88af052c5ca292b3d25c95d.jpg, boxes: tensor([[ 50.,  75., 375., 500.]]), labels: tensor([15])
# Image train/2008_003059_jpg.rf.04c920ece8856c2356335ae4edb1db18.jpg, boxes: tensor([[144., 115., 271., 175.]]), labels: tensor([1])
# Image train/2011_006141_jpg.rf.a6024d7ee9e599ccc1ee0c9f102affaa.jpg, boxes: tensor([[254.,  43., 400., 375.]]), labels: tensor([15])
# Image train/2010_001981_jpg.rf.9e7fc01880d0d5707055885c51b40b65.jpg, boxes: tensor([[  1.,  24., 420., 366.],
#         [  1.,   1., 193., 162.],
#         [409.,   1., 474.,  75.]]), labels: tensor([7, 7, 9])
# Image train/2011_000569_jpg.rf.8459fafe2ed516d1f1871379b2aca519.jpg, boxes: tensor([[130., 111., 430., 307.],
#         [  1., 191., 119., 296.]]), labels: tensor([7, 7])
# Image train/2011_002111_jpg.rf.794b898ee6b2b380c8e6ca007d20ba99.jpg, boxes: tensor([[ 53., 103., 289., 319.],
#         [304.,  51., 338., 111.],
#         [442.,  40., 500.,  64.],
#         [331.,  24., 359., 108.],
#         [166., 171., 193., 199.],
#         [189., 163., 206., 197.]]), labels: tensor([ 2,  2,  7, 15,  5,  5])
# Image train/2009_003577_jpg.rf.87396d2b8582d36b3c92d87c089efe41.jpg, boxes: tensor([[  1., 231., 429., 375.],
#         [ 91.,  62., 261., 257.],
#         [263.,  72., 457., 314.],
#         [ 79., 149., 273., 242.],
#         [394., 166., 461., 375.],
#         [459., 142., 500., 194.],
#         [432.,  60., 500., 169.],
#         [454.,  94., 500., 169.],
#         [369.,  98., 390., 118.],
#         [344.,  89., 361., 130.],
#         [364., 131., 395., 163.],
#         [397., 125., 410., 159.],
#         [402., 119., 415., 148.]]), labels: tensor([11, 15, 15,  9,  9,  9, 15, 15, 15, 15, 11, 11, 11])
# Image train/2008_003552_jpg.rf.652e9f34691b426677432b8ccd322de7.jpg, boxes: tensor([[222., 132., 290., 239.]]), labels: tensor([15])
# Image train/2008_003100_jpg.rf.1540de20daf486a85c1ab5827f6b5527.jpg, boxes: tensor([[  1.,  57., 471., 340.],
#         [201.,  38., 355., 295.]]), labels: tensor([ 4, 15])
# Image train/2011_001951_jpg.rf.64698e3536fe82eac72ff41b288ed679.jpg, boxes: tensor([[107.,   4., 387., 332.],
#         [334., 156., 500., 313.],
#         [  1., 143., 176., 317.]]), labels: tensor([19, 19, 19])
# Image train/2011_000297_jpg.rf.9e65dfa092e0f94991807036b969b790.jpg, boxes: tensor([[  1.,   7., 499., 375.]]), labels: tensor([2])
# Image train/2011_002793_jpg.rf.3d40c9026b4d452b5ed92fa4150fc4ae.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2010_003326_jpg.rf.84ec591057d2d1ab924e2e4a617e294b.jpg, boxes: tensor([]), labels: tensor([], dtype=torch.int64)
# Image train/2008_000142_jpg.rf.8a8d457d5602d2fe2ffbe6ab9f764235.jpg, boxes: tensor([[109.,  75., 494., 333.],
#         [ 93., 159., 105., 188.],
#         [ 36., 100., 129., 333.]]), labels: tensor([13, 15, 15])
# Image train/2008_001302_jpg.rf.22d602bcd3b4b0c38971e7633c05ac7a.jpg, boxes: tensor([[202., 203., 245., 315.],
#         [104.,  55., 153., 118.],
#         [113., 124., 146., 175.]]), labels: tensor([15, 15, 15])
# Skipping batch with empty targets: [0, 0, 3, 3]
# Image train/2009_003232_jpg.rf.d385dfcdaa038ab228aea0723f243c3f.jpg, boxes: tensor([[ 61.,  88., 319., 360.]]), labels: tensor([13])
# Image train/2011_006293_jpg.rf.17ec6a1feaf4b14a421ea41cce1858c7.jpg, boxes: tensor([[396., 155., 460., 263.],
#         [ 46., 174., 131., 269.]]), labels: tensor([15, 15])
# Image train/2012_001154_jpg.rf.9ca83f48f775b2a103df5df56004abab.jpg, boxes: tensor([[141.,  78., 204., 217.]]), labels: tensor([15])
# Image train/2007_009618_jpg.rf.a42fccf5d48a5df6291b4019cae80abb.jpg, boxes: tensor([[183., 230., 305., 311.],
#         [391., 273., 500., 321.],
#         [191., 170., 251., 309.]]), labels: tensor([ 2,  2, 15])
# Image train/2011_001726_jpg.rf.ea21e1c74f14ec61d05f2bd72b5009fd.jpg, boxes: tensor([[155., 132., 233., 199.],
#         [291.,  56., 395., 251.]]), labels: tensor([20, 16])
# Image train/2008_008697_jpg.rf.42c573259bc422562292cac10e8d0e76.jpg, boxes: tensor([[ 35.,   1., 375., 500.],
#         [  1., 283.,  27., 330.],
#         [196.,  88., 307., 407.]]), labels: tensor([19, 19, 15])
# Image train/2012_002308_jpg.rf.151f5091f672776049d2e287f7b678c3.jpg, boxes: tensor([[232., 157., 375., 500.]]), labels: tensor([15])
# Image train/2010_001562_jpg.rf.df4742a1a89616e6ee661b0fe2831138.jpg, boxes: tensor([[413., 120., 500., 252.]]), labels: tensor([20])
# Image train/2008_007334_jpg.rf.b6bccc99787700b6d7eab65a1debd7a2.jpg, boxes: tensor([[  1., 144., 170., 462.],
#         [106.,  60., 286., 458.]]), labels: tensor([17, 15])
# Image train/2010_006727_jpg.rf.76e1b20683b979a3fd60780906e66af7.jpg, boxes: tensor([[ 87.,  72., 189., 336.],
#         [176.,  83., 277., 336.]]), labels: tensor([15, 15])
# Image train/2011_006151_jpg.rf.887c5a018f7f31c04b5211bdaf2a9aea.jpg, boxes: tensor([[266., 125., 399., 329.]]), labels: tensor([15])
# Image train/2009_001081_jpg.rf.d5c854dc1763e6be805e3a4df9aee73e.jpg, boxes: tensor([[  1.,   1., 500., 375.],
#         [121.,  59., 500., 375.]]), labels: tensor([18,  8])
# Image train/2008_000795_jpg.rf.4709db24111a52f86003d881b651b4f6.jpg, boxes: tensor([[  1.,  82., 232., 332.],
#         [187.,  94., 323., 332.],
#         [291., 126., 500., 331.],
#         [216., 291., 252., 332.]]), labels: tensor([15, 15, 15,  5])
# Image train/2007_001884_jpg.rf.c6ada8b179696285bbac4e48e0d2e82f.jpg, boxes: tensor([[189., 217., 201., 245.],
#         [200., 216., 311., 251.],
#         [309., 213., 416., 245.],
#         [130., 112., 435., 211.]]), labels: tensor([6, 6, 6, 1])
# Image train/2009_001068_jpg.rf.c982e979399b4c72fc29c830b6f2f880.jpg, boxes: tensor([[ 93.,  85., 306., 482.]]), labels: tensor([15])
# Image train/2008_007293_jpg.rf.67d3a34fd229c1b383b9fe21c5e6d23c.jpg, boxes: tensor([[200., 276., 375., 500.]]), labels: tensor([9])
# Image train/2011_003878_jpg.rf.9bb2bd632eab15a0bcbcb3bbf31f246a.jpg, boxes: tensor([[106.,  75., 273., 334.]]), labels: tensor([15])
# Image train/2010_001776_jpg.rf.a69597215b0de8eb094bea761e446518.jpg, boxes: tensor([[ 94., 146., 416., 374.],
#         [ 38.,  17., 385., 225.]]), labels: tensor([12, 12])
# Image train/2012_000413_jpg.rf.6bd5bab428a21986bceb0a379ed1cf96.jpg, boxes: tensor([[ 79.,   7., 267., 316.]]), labels: tensor([15])
# Image train/2012_000028_jpg.rf.80d7469ed01f25f75c2b4f094f2f4358.jpg, boxes: tensor([[111., 178., 229., 333.]]), labels: tensor([15])
# Image train/2010_000740_jpg.rf.4f1ca98072bceafe18f637fbe66a191d.jpg, boxes: tensor([[  1.,   1., 315., 375.],
#         [364., 162., 381., 212.],
#         [376., 171., 405., 247.]]), labels: tensor([19, 15, 15])
# Image train/2011_001110_jpg.rf.b6ea0cccf07d137681d945e6f684d9fa.jpg, boxes: tensor([[277., 163., 410., 231.],
#         [  1., 159., 233., 314.],
#         [124., 157., 246., 209.],
#         [223., 154., 293., 180.],
#         [ 74., 143., 125., 166.],
#         [385., 164., 410., 189.],
#         [  1., 140.,  63., 162.],
#         [215., 150., 259., 172.],
#         [485., 169., 500., 194.],
#         [363., 154., 405., 173.],
#         [317., 136., 409., 168.]]), labels: tensor([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 6])
# Image train/2008_000262_jpg.rf.e094641152d0bb803f7708ae16e651c5.jpg, boxes: tensor([[ 23., 143., 430., 330.]]), labels: tensor([4])
# Image train/2011_005474_jpg.rf.3dfd2c21ae2bcaf31c412837d37455d9.jpg, boxes: tensor([[116.,  41., 284., 297.]]), labels: tensor([15])
# Image train/2011_005585_jpg.rf.a71029a1ec4e9c7854b4ebea1a6d5144.jpg, boxes: tensor([[221.,  41., 500., 375.]]), labels: tensor([15])
# Image train/2011_000383_jpg.rf.c0224e50cc84bf20c2448fd12d6d875a.jpg, boxes: tensor([[ 63.,  16., 228., 131.],
#         [139., 106., 278., 291.],
#         [ 72., 288., 202., 500.],
#         [152., 475., 174., 500.]]), labels: tensor([ 9,  9,  9, 15])
# Image train/2010_005241_jpg.rf.ff794281fa6d08145a7e3910ad3548e4.jpg, boxes: tensor([[ 53.,  75., 399., 500.]]), labels: tensor([8])
# Image train/2010_000608_jpg.rf.738ac976fed2a597140de1f3ef9fdc4f.jpg, boxes: tensor([[ 31.,  11., 458., 412.]]), labels: tensor([12])
# Image train/2010_004173_jpg.rf.a7c125bd71bf337320a100205784ddc0.jpg, boxes: tensor([[  1., 293., 214., 500.]]), labels: tensor([9])
# Image train/2008_006882_jpg.rf.7d65c4e4ea5e1262d9bb1fa09faeff53.jpg, boxes: tensor([[  1.,  93., 306., 500.]]), labels: tensor([3])
# Image train/2007_009015_jpg.rf.1f7527c4292ea3e3e463498ecf44b2e7.jpg, boxes: tensor([[232., 128., 431., 242.],
#         [  1., 211.,  54., 333.],
#         [114., 196., 153., 220.],
#         [213., 202., 233., 228.],
#         [ 72., 199., 113., 221.],
#         [ 63., 198.,  75., 216.]]), labels: tensor([6, 7, 7, 7, 7, 7])
# Image train/2011_002987_jpg.rf.ac24eeaf7c9c65bb2d1725385ee72665.jpg, boxes: tensor([[ 95.,  39., 324., 326.],
#         [191., 219., 236., 294.]]), labels: tensor([19, 15])
# Image train/2010_002573_jpg.rf.4ef9b9691a5c2b42a42be75ae35f9483.jpg, boxes: tensor([[ 63.,  79., 342., 352.]]), labels: tensor([8])
# Image train/2008_000804_jpg.rf.63110d7e65ece0905fdff42a7ac1b9e8.jpg, boxes: tensor([[ 60.,  98., 466., 296.]]), labels: tensor([1])
# Image train/2010_002070_jpg.rf.f6094f7cfbe2a4ec6d8c6c8c4a7a568b.jpg, boxes: tensor([[392., 208., 444., 333.],
#         [  6., 230.,  30., 333.],
#         [ 26.,  97., 204., 333.],
#         [260.,  92., 405., 333.],
#         [140., 223., 344., 333.]]), labels: tensor([ 9,  9, 15, 15, 11])
# Image train/2011_003228_jpg.rf.7a07a3ead9a5bdc6110a99fba4d1d75d.jpg, boxes: tensor([[  1.,   1., 500., 345.]]), labels: tensor([19])
# Image train/2009_004232_jpg.rf.67072583ebed177c0536818260c2c9b1.jpg, boxes: tensor([[  1.,  48., 213., 243.],
#         [ 23.,   1., 499., 368.]]), labels: tensor([7, 7])
# Image train/2008_006447_jpg.rf.24d7ba475980aefe42940bfb173f616b.jpg, boxes: tensor([[102.,  44., 288., 364.]]), labels: tensor([3])
# Image train/2011_003548_jpg.rf.2307cf0b8a8abc76e9ab2e1a141d66e1.jpg, boxes: tensor([[ 72.,  57., 246., 335.],
#         [259.,   1., 500., 335.],
#         [  3.,  86.,  98., 288.]]), labels: tensor([15, 15, 15])
# Image train/2012_000174_jpg.rf.4911073754e7a23cc5c1104c7ac7a330.jpg, boxes: tensor([[386., 122., 478., 306.]]), labels: tensor([15])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 70
#      68         losses.backward()
#      69         optimizer.step()
# ---> 70         running_loss += losses.item()
#      72     print(f"Epoch {epoch+1}, Loss: {running_loss/len(train_loader)}")
#      75 # Evaluate the model on the validation set
#
# KeyboardInterrupt:

# %%
# Extract train percentages and metrics from the results
train_percentages = [i * 10 for i in range(1, 10)]
val_metrics = [results[f"split_{i}"] for i in range(1, 10)]
test_metrics = [test_results[f"split_{i}"] for i in range(1, 10)]

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train_percentages, val_metrics, marker='o', label='Validation Mean IoU', color='blue')
plt.plot(train_percentages, test_metrics, marker='x', label='Test Mean IoU', color='green')

# Customize plot appearance
plt.xlabel('Train Percentage (%)')
plt.ylabel('Mean IoU')
plt.title('Validation and Test Mean IoU vs. Train Percentage')
plt.legend()
plt.grid(True)  # Adding grid for better readability
plt.xticks(train_percentages)  # Set x-axis ticks at each train percentage

# Display the plot
plt.show()

# %%
# Example data based on the earlier context
train_percentages = [i * 10 for i in range(1, 10)]

# Creating a DataFrame for the table
df = pd.DataFrame({
    "Train Percentage": train_percentages,
    "Validation Mean IoU": np.round(val_metrics, 2),
    "Test Mean IoU": np.round(test_metrics, 2)
}).set_index("Train Percentage")

# %%
df

# %% [markdown]
# # Pascal VOC 2012 Dataset with Multiple Classes

# %%
# Step 1: Load Pascal VOC 2012 dataset and handle multiple classes
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Pascal VOC specific transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Load Pascal VOC 2012 dataset
train_dataset = datasets.VOCDetection(
    root='path_to_data',  # Replace with the correct path to Pascal VOC 2012
    year='2012',
    image_set='train',
    download=True,
    transform=transform
)

val_dataset = datasets.VOCDetection(
    root='path_to_data',
    year='2012',
    image_set='val',
    download=True,
    transform=transform
)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
# Step 2: Modify the model architecture for multi-class detection
import torchvision.models as models
from torch import nn

# Load pre-trained ResNet model and modify for multi-class object detection
model = models.resnet50(pretrained=True)

# Modify the final layer for VOC's 20 classes
num_classes = 20  # Pascal VOC has 20 classes
model.fc = nn.Linear(model.fc.in_features, num_classes)

# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
# Step 3: Define the training loop and evaluation with IoU for each class
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from sklearn.metrics import jaccard_score

# Set up optimizer and loss function
optimizer = Adam(model.parameters(), lr=0.001)
criterion = CrossEntropyLoss()

# Training loop and evaluation
def train_model(model, train_loader, val_loader, num_epochs=10):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        
        # Training phase
        for images, targets in train_loader:
            images = images.to(device)
            labels = [target['annotation']['object'] for target in targets]
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(train_loader)}")

        # Evaluation on validation set with IoU for each class
        model.eval()
        with torch.no_grad():
            all_preds, all_labels = [], []
            for images, targets in val_loader:
                images = images.to(device)
                labels = [target['annotation']['object'] for target in targets]
                outputs = model(images)

                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                labels = labels.cpu().numpy()

                all_preds.extend(preds)
                all_labels.extend(labels)

            iou_score = jaccard_score(all_labels, all_preds, average=None)
            print(f"Validation IoU per class: {iou_score}")
